# %% [markdown]
# # TASK 1.1: TOKENIZATION
# _ splitting text files into words _

# %% [markdown]
# ## Text file: Offensive

# %%
import pathlib
import string

# %% [markdown]
# ### Read in txt files: offensive/val_text.txt

# %%
file_path_val = pathlib.Path('datasets/offensive/val_text.txt')

with open(file_path_val, 'r') as f:
    text_val = f.read()       
    f.close()
    
words_val_txt = text_val[1:].split()

print(words_val_txt[:100])
# Out:
# ['user', '@user', 'WiiU', 'is', 'not', 'even', 'a', 'real', 'console.', '@user', '@user', '@user', 'If', 'he', 'is', 'from', 'AZ', 'I', 'would', 'put', 'my', 'money', 'on', 'sex', 'with', 'underage', 'kids.', '@user', 'I', 'thought', 'Canada', 'had', 'strict', 'gun', 'control.', 'Help', 'me', 'understand', 'what', 'is', 'happening.', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', 'Following', 'all', '#Maga', 'patriots', 'please', 'follow', 'back', '👍', '#LionsDen', '🦁', '#MAGA2KAG', '🇺🇸', '1', 'Minute', 'of', 'Truth:', 'Gun', 'Control', 'via', '@user', '@user', '@user', '@user', 'We', 'could', 'help', 'if', 'you', 'are', 'London', 'based', '😊', '@user', '@user', 'There', 'r', '65', 'million', 'that', 'can', 'sign', 'to', 'the']

# %%
file_path_train = pathlib.Path('datasets/offensive/train_text.txt')


with open(file_path_train, 'r') as f:
    text_train = f.read()       
    f.close()
    
words_train_txt = text_train[1:].split()
print(words_train_txt[:100])
# Out:
# ['user', 'Bono...', 'who', 'cares.', 'Soon', 'people', 'will', 'understand', 'that', 'they', 'gain', 'nothing', 'from', 'following', 'a', 'phony', 'celebrity.', 'Become', 'a', 'Leader', 'of', 'your', 'people', 'instead', 'or', 'help', 'and', 'support', 'your', 'fellow', 'countrymen.', '@user', 'Eight', 'years', 'the', 'republicans', 'denied', 'obama’s', 'picks.', 'Breitbarters', 'outrage', 'is', 'as', 'phony', 'as', 'their', 'fake', 'president.', '@user', 'Get', 'him', 'some', 'line', 'help.', 'He', 'is', 'gonna', 'be', 'just', 'fine.', 'As', 'the', 'game', 'went', 'on', 'you', 'could', 'see', 'him', 'progressing', 'more', 'with', 'his', 'reads.', 'He', 'brought', 'what', 'has', 'been', 'missing.', 'The', 'deep', 'ball', 'presence.', 'Now', 'he', 'just', 'needs', 'a', 'little', 'more', 'time', '@user', '@user', 'She', 'is', 'great.', 'Hi', 'Fiona!', '@user']

# %%
file_path_test = pathlib.Path('datasets/offensive/test_text.txt')


with open(file_path_test, 'r') as f:
    text_test = f.read()       
    f.close()
    
words_test_txt = text_test[1:].split()
print(words_test_txt[:100])
# Out:
# ['ibelieveblaseyford', 'is', 'liar', 'she', 'is', 'fat', 'ugly', 'libreal', '#snowflake', 'she', 'sold', 'her', 'herself', 'to', 'get', 'some', 'cash', '!!', 'From', 'dems', 'and', 'Iran', '!', 'Why', 'she', 'spoke', 'after', '#JohnKerryIranMeeting', '?', '@user', '@user', '@user', 'I', 'got', 'in', 'a', 'pretty', 'deep', 'debate', 'with', 'my', 'friend', 'and', 'she', 'told', 'me', 'that', 'latinos', 'for', 'Trump', 'and', 'blacks', 'for', 'Trump', 'were', 'paid', 'supporters', '😂', 'then', 'I', 'said', 'you', 'mean', 'antifa', 'are', 'paid', 'domestic', 'terrorist', 'and', 'she', 'said', 'No', 'they', 'are', 'anti-fascist', 'then', 'I', 'said', 'they', 'are', 'the', 'fascist', 'are', 'you', 'kidding', 'me?!', '...if', 'you', 'want', 'more', 'shootings', 'and', 'more', 'death,', 'then', 'listen', 'to', 'the', 'ACLU,', 'Black']

# %% [markdown]
# ### Remove punctuations from txt files

# %%
def del_punctuations(words):

    punctuation_table = str.maketrans('', '', string.punctuation)

    words = [word.translate(punctuation_table).lower() for word in words]
    return words

cleaned_val_words = del_punctuations(words_val_txt[:100])
cleaned_train_words = del_punctuations(words_train_txt[:100])
cleaned_test_words = del_punctuations(words_test_txt[:100])

print('val_text.txt:\n',cleaned_val_words,'\n')

print('\nval_train.txt:\n',cleaned_train_words, '\n')

print('\nval_test.txt:\n',cleaned_test_words,'\n')
# Out:
# val_text.txt:
#  ['user', 'user', 'wiiu', 'is', 'not', 'even', 'a', 'real', 'console', 'user', 'user', 'user', 'if', 'he', 'is', 'from', 'az', 'i', 'would', 'put', 'my', 'money', 'on', 'sex', 'with', 'underage', 'kids', 'user', 'i', 'thought', 'canada', 'had', 'strict', 'gun', 'control', 'help', 'me', 'understand', 'what', 'is', 'happening', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'following', 'all', 'maga', 'patriots', 'please', 'follow', 'back', '👍', 'lionsden', '🦁', 'maga2kag', '🇺🇸', '1', 'minute', 'of', 'truth', 'gun', 'control', 'via', 'user', 'user', 'user', 'user', 'we', 'could', 'help', 'if', 'you', 'are', 'london', 'based', '😊', 'user', 'user', 'there', 'r', '65', 'million', 'that', 'can', 'sign', 'to', 'the']
#
#
# val_train.txt:
#  ['user', 'bono', 'who', 'cares', 'soon', 'people', 'will', 'understand', 'that', 'they', 'gain', 'nothing', 'from', 'following', 'a', 'phony', 'celebrity', 'become', 'a', 'leader', 'of', 'your', 'people', 'instead', 'or', 'help', 'and', 'support', 'your', 'fellow', 'countrymen', 'user', 'eight', 'years', 'the', 'republicans', 'denied', 'obama’s', 'picks', 'breitbarters', 'outrage', 'is', 'as', 'phony', 'as', 'their', 'fake', 'president', 'user', 'get', 'him', 'some', 'line', 'help', 'he', 'is', 'gonna', 'be', 'just', 'fine', 'as', 'the', 'game', 'went', 'on', 'you', 'could', 'see', 'him', 'progressing', 'more', 'with', 'his', 'reads', 'he', 'brought', 'what', 'has', 'been', 'missing', 'the', 'deep', 'ball', 'presence', 'now', 'he', 'just', 'needs', 'a', 'little', 'more', 'time', 'user', 'user', 'she', 'is', 'great', 'hi', 'fiona', 'user']
#
#
# val_test.txt:
#  ['ibelieveblaseyford', 'is', 'liar', 'she', 'is', 'fat', 'ugly', 'libreal', 'snowflake', 'she', 'sold', 'her', 'herself', 'to', 'get', 'some', 'cash', '', 'from', 'dems', 'and', 'iran', '', 'why', 'she', 'spoke', 'after', 'johnkerryiranmeeting', '', 'user', 'user', 'user', 'i', 'got', 'in', 'a', 'pretty', 'deep', 'debate', 'with', 'my', 'friend', 'and', 'she', 'told', 'me', 'that', 'latinos', 'for', 'trump', 'and', 'blacks', 'for', 'trump', 'were', 'paid', 'supporters', '😂', 'then', 'i', 'said', 'you', 'mean', 'antifa', 'are', 'paid', 'domestic', 'terrorist', 'and', 'she', 'said', 'no', 'they', 'are', 'antifascist', 'then', 'i', 'said', 'they', 'are', 'the', 'fascist', 'are', 'you', 'kidding', 'me', 'if', 'you', 'want', 'more', 'shootings', 'and', 'more', 'death', 'then', 'listen', 'to', 'the', 'aclu', 'black']

# %%
from nltk import sent_tokenize
#nltk.download('punkt')

def token_sentences(text):
    sentences = sent_tokenize(text)
    return sentences

sentences_val_txt = token_sentences(text_val)   
sentences_train_txt = token_sentences(text_train)
sentences_test_txt = token_sentences(text_test)   

#print(sentences_val_txt[:10])
#print(sentences_train_txt[:10])
#print(sentences_test_txt[:10])
# Out:
# ['@user @user WiiU is not even a real console.', '@user @user @user If he is from AZ I would put my money on sex with underage kids.', '@user I thought Canada had strict gun control.', 'Help me understand what is happening.', "@user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user Following all #Maga patriots please follow back 👍  #LionsDen 🦁  #MAGA2KAG 🇺🇸 \n1 Minute of Truth: Gun Control via @user \n@user @user @user We could help if you are London based 😊 \n@user @user There r 65 million that can sign to the affect that they didn't vote for an asshole.", '@user What do you mean how Chelsea have kept Hazard?', 'He is bloody one of Chelsea key player and best in the world right now.', 'And one big club in Europe.', 'What do you want more?', "@user @user @user @user You've got nerve pointing the finger at other states with the murder rate you have.", "How's that gun control working for you?", 'Own it \n@user Is that federal investigation group by chance Chinese?', 'A congressional aid?', 'Please respond Senator as a constituent is wanting disclosure.', 'You are accountable for all you do and say.', 'Do not contribute to any form of collusion.', 'Obey the law.', "@user @user That's the problem with conservatives.", 'They mix up etiquette and talent.', 'Both in moderation.', '@user @user Liberals have taken over every major city here but Ft Worth \n@user @user Target environment keeps getting richer.', '@user All we need now is a gang sign \n@user @user Will @user or @user ask for some sort of gun control or once again do NOTHING?', 'They seem to be really good at doing NOTHING!', '#StopKavanaugh #Sendhim home #@USER   Kavanaugh Allegation: Conservatives Go Soft on Teen Crime #SmartNews \n@user People need to get a life.', 'She is a beautiful lady doing her job.', 'They need to leave her alone and leave Tessa alone.', 'Doesn’t matter what you are everybody needs to show love not hate.', '@user Beyond absurd!', 'Ehat flavor kool-aide is being dispensed at the water cooler?', "#GroupThinkStinks \n@user It has been being de-created slowly and stealthily since the CONservatives came to power... Hunt's done a sterling job.", '@user @user Leave it to me please.', 'I know he is your son but I am his awesome aunt.', '@user She is!', "🙏🏻❤️ \n@user @user @user They’ll never get enough Antifa who even know where the library is...I think we can relax 😊 \n@user A whore's book being published!", 'All the looney liberals run out and buy it \n@user @user LOVE HER!!', 'She is a BADASS!', '@user @user @user You never expect Nikki Haley in your mentions but then there she is \n@user @user First law — sensible fucking gun control!', '@user @user All bull!', '@user Who talks shit on buff chicken dip dude it’s buff chicken dip \n-Willie you just lost over half of your fans by getting involved in politics!!', 'Fan no more!!', 'I cannot believe you support open borders and gun control!!', 'You have smoked too much dope!', 'I guess that is what you and Beta have in common!', '- Had a nice visit with Mommie dearest.', 'I really had to bribe her with Diet Pepsi to eat the rest of her dinner..... 😂😭🤦🏾\u200d♀️ She is something else!!', 'Love that lady.... \n$10 B/W commissions are still available!', 'Please DM if you are interested!', '#artistforhire #commission #robots #anthro #furry #monstergirls #cyclops #pokemon #magikarp #catgirls #possum #artistsontwitter \n@user @user Not now Hell no he offered that last year no go now.', '@user @user @user Planned Parenthood provides millions with CONTRACEPTION - thereby eliminating an unplanned pregnancy for most; an unplanned pregnancy that doesn’t potentially result in an abortion.', 'Conservatives possess no critical thinking skills whatsoever!', '@user I told myself this but no matter how much I try life keeps biting me in the ass \n@user Contribute to their Maximum Capacity"" - Translation: ""Vote for guys with a criminal record like me who occasionally wear dresses and  ...

# %% [markdown]
# ### Number of words in each tokenization variables

# %%
from nltk.tokenize import word_tokenize

def tokenization(words, text):

    tokens = word_tokenize(text[1:])
    words = [token.lower() for token in tokens if token.isalpha()]
    
    return words

token_val = tokenization(cleaned_val_words, text_val)
token_train = tokenization(cleaned_train_words, text_train)
token_test = tokenization(cleaned_test_words, text_test)

print(f'Number of words in tokenization for val_text: {len(token_val)}')
print(f'Number of words in tokenization for val_train: {len(token_train)}')
print(f'Number of words in tokenization for val_test: {len(token_test)}')
# Out:
# Number of words in tokenization for val_text: 30491
# Number of words in tokenization for val_train: 258990
# Number of words in tokenization for val_test: 19711

# %% [markdown]
# # My approach to task 1

# %%
#This is the ideal tokenization from the library we were supposed to compare it with
from nltk.tokenize import TweetTokenizer
tknzr = TweetTokenizer()

sentence = 'Heroin is my passion.'

tknzr.tokenize(sentence)
# Out:
# ['Heroin', 'is', 'my', 'passion', '.']

# %%
#Recreate
import re
import pathlib

file_path_train = pathlib.Path('datasets/offensive/train_text.txt')

token_pattern = re.compile(r'\w+')

with open(file_path_train, 'r') as f:
    line = f.readline()
    tokens = []
    while line:
        line = f.readline()
        print(line)
        print("OUR beta tokenizer",re.findall(token_pattern,line))
        print("DESIRED  tokenizer",tknzr.tokenize(line))
        print('\n')
# Out:
# @user Eight years the republicans denied obama’s picks. Breitbarters outrage is as phony as their fake president.
#
# OUR beta tokenizer ['user', 'Eight', 'years', 'the', 'republicans', 'denied', 'obama', 's', 'picks', 'Breitbarters', 'outrage', 'is', 'as', 'phony', 'as', 'their', 'fake', 'president']
# DESIRED  tokenizer ['@user', 'Eight', 'years', 'the', 'republicans', 'denied', 'obama', '’', 's', 'picks', '.', 'Breitbarters', 'outrage', 'is', 'as', 'phony', 'as', 'their', 'fake', 'president', '.']
#
#
# @user Get him some line help. He is gonna be just fine. As the game went on you could see him progressing more with his reads. He brought what has been missing. The deep ball presence. Now he just needs a little more time
#
# OUR beta tokenizer ['user', 'Get', 'him', 'some', 'line', 'help', 'He', 'is', 'gonna', 'be', 'just', 'fine', 'As', 'the', 'game', 'went', 'on', 'you', 'could', 'see', 'him', 'progressing', 'more', 'with', 'his', 'reads', 'He', 'brought', 'what', 'has', 'been', 'missing', 'The', 'deep', 'ball', 'presence', 'Now', 'he', 'just', 'needs', 'a', 'little', 'more', 'time']
# DESIRED  tokenizer ['@user', 'Get', 'him', 'some', 'line', 'help', '.', 'He', 'is', 'gonna', 'be', 'just', 'fine', '.', 'As', 'the', 'game', 'went', 'on', 'you', 'could', 'see', 'him', 'progressing', 'more', 'with', 'his', 'reads', '.', 'He', 'brought', 'what', 'has', 'been', 'missing', '.', 'The', 'deep', 'ball', 'presence', '.', 'Now', 'he', 'just', 'needs', 'a', 'little', 'more', 'time']
#
#
# @user @user She is great. Hi Fiona!
#
# OUR beta tokenizer ['user', 'user', 'She', 'is', 'great', 'Hi', 'Fiona']
# DESIRED  tokenizer ['@user', '@user', 'She', 'is', 'great', '.', 'Hi', 'Fiona', '!']
#
#
# @user She has become a parody unto herself? She has certainly taken some heat for being such an....well idiot. Could be optic too  Who know with Liberals  They're all optics.  No substance
#
# OUR beta tokenizer ['user', 'She', 'has', 'become', 'a', 'parody', 'unto', 'herself', 'She', 'has', 'certainly', 'taken', 'some', 'heat', 'for', 'being', 'such', 'an', 'well', 'idiot', 'Could', 'be', 'optic', 'too', 'Who', 'know', 'with', 'Liberals', 'They', 're', 'all', 'optics', 'No', 'substance']
# DESIRED  tokenizer ['@user', 'She', 'has', 'become', 'a', 'parody', 'unto', 'herself', '?', 'She', 'has', 'certainly', 'taken', 'some', 'heat', 'for', 'being', 'such', 'an', '...', 'well', 'idiot', '.', 'Could', 'be', 'optic', 'too', 'Who', 'know', 'with', 'Liberals', "They're", 'all', 'optics', '.', 'No', 'substance']
#
#
# @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user This is the VetsResistSquadron"" is Bullshit.. They are girl scout veterans, I have never met any other veterans or served with anyone that was a gun control advocate? Have you?""
#
# OUR beta tokenizer ['user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'This', 'is', 'the', 'VetsResistSquadron', 'is', 'Bullshit', 'They', 'are', 'girl', 'scout', 'veterans', 'I', 'have', 'never', 'met', 'any', 'other', 'veterans', 'or', 'served', 'with', 'anyone', 'that', 'was', 'a', 'gun', 'control', 'advocate', 'Have', 'you']
# DESIRED  tokenizer ['@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', 'This', 'is', 'the', 'VetsResistSquadron', '"', '"', 'is', 'Bullshit', '..', 'They', 'are', 'girl', 'scout', 'veterans', ',', 'I', 'have', 'never', 'met', 'any', 'other', 'veterans', 'or', 'served', 'with', 'anyone', 'that', 'was', 'a', 'gun', 'control', 'advocate', '?', 'Have', 'you', '?', '"', '"']
#
#
# @user Your looking more like a plant #maga #walkaway
#
# OUR beta tokenizer ['user', 'Your', 'looking', 'more', 'like', 'a', 'plant', 'maga', 'walkaway']
# DESIRED  tokenizer ['@user', 'Your', 'looking', 'more', 'like', 'a', 'plant', '#maga', '#walkaway']
#
#
# @user @user Lol. Except he’s the most successful president in our lifetimes. He’s undone most of the damage Obummer did and set America on the right path again. #MAGA
#
# OUR beta tokenizer ['user', 'user', 'Lol', 'Except', 'he', 's', 'the', 'most', 'successful', 'president', 'in', 'our', 'lifetimes', 'He', 's', 'undone', 'most', 'of', 'the', 'damage', 'Obummer', 'did', 'and', 'set', 'America', 'on', 'the', 'right', 'path', 'again', 'MAGA']
# DESIRED  tokenizer ['@user', '@user', 'Lol', '.', 'Except', 'he', '’', 's', 'the', 'most', 'successful', 'president', 'in', 'our', 'lifetimes', '.', 'He', '’', 's', 'undone', 'most', 'of', 'the', 'damage', 'Obummer', 'did', 'and', 'set', 'America', 'on', 'the', 'right', 'path', 'again', '.', '#MAGA']
#
#
# @user Been a Willie fan since before most of you were born....LOVE that he is holding a rally with Beto.... Exactly WHICH fans are furious?  Could you give some specifics?
#
# OUR beta tokenizer ['user', 'Been', 'a', 'Willie', 'fan', 'since', 'before', 'most', 'of', 'you', 'were', 'born', 'LOVE', 'that', 'he', 'is', 'holding', 'a', 'rally', 'with', 'Beto', 'Exactly', 'WHICH', 'fans', 'are', 'furious', 'Could', 'you', 'give', 'some', 'specifics']
# DESIRED  tokenizer ['@user', 'Been', 'a', 'Willie', 'fan', 'since', 'before', 'most', 'of', 'you', 'were', 'born', '...', 'LOVE', 'that', 'he', 'is', 'holding', 'a', 'rally', 'with', 'Beto', '...', 'Exactly', 'WHICH', 'fans', 'are', 'furious', '?', 'Could', 'you', 'give', 'some', 'specifics', '?']
#
#
# @user Here's a link to my channel with a plethora of topics to peruse:
#
# OUR beta tokenizer ['user', 'Here', 's', 'a', 'link', 'to', 'my', 'channel', 'with', 'a', 'plethora', 'of', 'topics', 'to', 'peruse']
# DESIRED  tokenizer ['@user', "Here's", 'a', 'link', 'to', 'my', 'channel', 'with', 'a', 'plethora', 'of', 'topics', 'to', 'peruse', ':']
#
#
# @user Antifa would burn a Conservatives house down and CNN would be there lighting the torches &amp; throwing gas on the flames.
#
# OUR beta tokenizer ['user', 'Antifa', 'would', 'burn', 'a', 'Conservatives', 'house', 'down', 'and', 'CNN', 'would', 'be', 'there', 'lighting', 'the', 'torches', 'amp', 'throwing', 'gas', 'on', 'the', 'flames']
# DESIRED  tokenizer ['@user', 'Antifa', 'would', 'burn', 'a', 'Conservatives', 'house', 'down', 'and', 'CNN', 'would', 'be', 'there', 'lighting', 'the', 'torches', '&', 'throwing', 'gas', 'on', 'the', 'flames', '.']
#
#
# @user They cite Jones being banned for violating Twitter's ToS. There are blue checkmarks spewing the same, if not worse, kind of shit. If you are going to play the anyone can get banned"" card. Shouldn't these people also receive bans and suspensions? #VerifiedHate""
#
# OUR beta tokenizer ['user', 'They', 'cite', 'Jones', 'being', 'banned', 'for', 'violating', 'Twitter', 's', 'ToS', 'There', 'are', 'blue', 'checkmarks', 'spewing', 'the', 'same', 'if', 'not', 'worse', 'kind', 'of', 'shit', 'If', 'you', 'are', 'going', 'to', 'play', 'the', 'anyone', 'can', 'get', 'banned', 'card', 'Shouldn', 't', 'these', 'people', 'also', 'receive', 'bans', 'and', 'suspensions', 'VerifiedHate']
# DESIRED  tokenizer ['@user', 'They', 'cite', 'Jones', 'being', 'banned', 'for', 'violating', "Twitter's", 'ToS', '.', 'There', 'are', 'blue', 'checkmarks', 'spewing', 'the', 'same', ',', 'if', 'not', 'worse', ',', 'kind', 'of', 'shit', '.', 'If', 'you', 'are', 'going', 'to', 'play', 'the', 'anyone', 'can', 'get', 'banned', '"', '"', 'card', '.', "Shouldn't", 'these', 'people', 'also', 'receive', 'bans', 'and', 'suspensions', '?', '#VerifiedHate', '"', '"']
#
#
# @user Friend ordered 100 pair of Levi’s and then called to cancel! Over Gun control! Wow getting wild!
#
# OUR beta tokenizer ['user', 'Friend', 'ordered', '100', 'pair', 'of', 'Levi', 's', 'and', 'then', 'called', 'to', 'cancel', 'Over', 'Gun', 'control', 'Wow', 'getting', 'wild']
# DESIRED  tokenizer ['@user', 'Friend', 'ordered', '100', 'pair', 'of', 'Levi', '’', 's', 'and', 'then', 'called', 'to', 'cancel', '!', 'Over', 'Gun', 'control', '!', 'Wow', 'getting', 'wild', '!']
#
#
# @user @user Lmfaoooooo
#
# OUR beta tokenizer ['user', 'user', 'Lmfaoooooo']
# DESIRED  tokenizer ['@user', '@user', 'Lmfaoooooo']
#
#
# @user Goodell should have been fired over a year ago. Looks like the owners will let him steer the ship right into the iceberg. Oh well.
#
# OUR beta tokenizer ['user', 'Goodell', 'should', 'have', 'been', 'fired', 'over', 'a', 'year', 'ago', 'Looks', 'like', 'the', 'owners', 'will', 'let', 'him', 'steer', 'the', 'ship', 'right', 'into', 'the', 'iceberg', 'Oh', 'well']
# DESIRED  tokenizer ['@user', 'Goodell', 'should', 'have', 'been', 'fired', 'over', 'a', 'year', 'ago', '.', 'Looks', 'like', 'the', 'owners', 'will', 'let', 'him', 'steer', 'the', 'ship', 'right', 'into', 'the', 'iceberg', '.', 'Oh', 'well', '.']
#
#
# @user @user This is a common message from liberals and Democrats.   Remember Nancy Pelosi we have to approve the health care package -Obama care and then we’ll see what’s in it afterwards🤔
#
# OUR beta tokenizer ['user', 'user', 'This', 'is', 'a', 'common', 'message', 'from', 'liberals', 'and', 'Democrats', 'Remember', 'Nancy', 'Pelosi', 'we', 'have', 'to', 'approve', 'the', 'health', 'care', 'package', 'Obama', 'care', 'and', 'then', 'we', 'll', 'see', 'what', 's', 'in', 'it', 'afterwards']
# DESIRED  tokenizer ['@user', '@user', 'This', 'is', 'a', 'common', 'message', 'from', 'liberals', 'and', 'Democrats', '.', 'Remember', 'Nancy', 'Pelosi', 'we', 'have', 'to', 'approve', 'the', 'health', 'care', 'package', '-', 'Obama', 'care', 'and', 'then', 'we', '’', 'll', 'see', 'what', '’', 's', 'in', 'it', 'afterwards', '🤔']
#
#
# @user also shitbiscuit stole most of the Tempe girls u can't blame that on me..
#
# OUR beta tokenizer ['user', 'also', 'shitbiscuit', 'stole', 'most', 'of', 'the', 'Tempe', 'girls', 'u', 'can', 't', 'blame', 'that', 'on', 'me']
# DESIRED  tokenizer ['@user', 'also', 'shitbiscuit', 'stole', 'most', 'of', 'the', 'Tempe', 'girls', 'u', "can't", 'blame', 'that', 'on', 'me', '..']
#
#
# @user @user Well, see, if I start talking at Dana about sensible gun control laws and she ignores me (or calls me a tragedy dry-humping whore"" as she did @user then we aren't having a conversation. I'm just talking into the void.""
#
# OUR beta tokenizer ['user', 'user', 'Well', 'see', 'if', 'I', 'start', 'talking', 'at', 'Dana', 'about', 'sensible', 'gun', 'control', 'laws', 'and', 'she', 'ignores', 'me', 'or', 'calls', 'me', 'a', 'tragedy', 'dry', 'humping', 'whore', 'as', 'she', 'did', 'user', 'then', 'we', 'aren', 't', 'having', 'a', 'conversation', 'I', 'm', 'just', 'talking', 'into', 'the', 'void']
# DESIRED  tokenizer ['@user', '@user', 'Well', ',', 'see', ',', 'if', 'I', 'start', 'talking', 'at', 'Dana', 'about', 'sensible', 'gun', 'control', 'laws', 'and', 'she', 'ignores', 'me', '(', 'or', 'calls', 'me', 'a', 'tragedy', 'dry-humping', 'whore', '"', '"', 'as', 'she', 'did', '@user', 'then', 'we', "aren't", 'having', 'a', 'conversation', '.', "I'm", 'just', 'talking', 'into', 'the', 'void', '.', '"', '"']
#
#
# @user @user You mean the way Hillary re-victimized all of Bills accusers?
#
# OUR beta tokenizer ['user', 'user', 'You', 'mean', 'the', 'way', 'Hillary', 're', 'victimized', 'all', 'of', 'Bills', 'accusers']
# DESIRED  tokenizer ['@user', '@user', 'You', 'mean', 'the', 'way', 'Hillary', 're-victimized', 'all', 'of', 'Bills', 'accusers', '?']
#
#
# GREAT COMEDY THERE CNN - NEWS?  NOT SO MUCH!  #MAGA!  #LICENSEREPORTERS!
#
# OUR beta tokenizer ['GREAT', 'COMEDY', 'THERE', 'CNN', 'NEWS', 'NOT', 'SO', 'MUCH', 'MAGA', 'LICENSEREPORTERS']
# DESIRED  tokenizer ['GREAT', 'COMEDY', 'THERE', 'CNN', '-', 'NEWS', '?', 'NOT', 'SO', 'MUCH', '!', '#MAGA', '!', '#LICENSEREPORTERS', '!']
#
#
# @user You are so fragile. It must be hard to live that way.
#
# OUR beta tokenizer ['user', 'You', 'are', 'so', 'fragile', 'It', 'must', 'be', 'hard', 'to', 'live', 'that', 'way']
# DESIRED  tokenizer ['@user', 'You', 'are', 'so', 'fragile', '.', 'It', 'must', 'be', 'hard', 'to', 'live', 'that', 'way', '.']
#
#
# @user All you do is lie. All congress does us lie.  MAGA.
#
# OUR beta tokenizer ['user', 'All', 'you', 'do', 'is', 'lie', 'All', 'congress', 'does', 'us', 'lie', 'MAGA']
# DESIRED  tokenizer ['@user', 'All', 'you', 'do', 'is', 'lie', '.', 'All', 'congress', 'does', 'us', 'lie', '.', 'MAGA', '.']
#
#
# @user Freudian slip.
#
# OUR beta tokenizer ['user', 'Freudian', 'slip']
# DESIRED  tokenizer ['@user', 'Freudian', 'slip', '.']
#
#
# @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user He also clarified that there is the water birth when we are physically born. Then there is the spiritual birth which is obviously when we spiritually die to our sinful flesh and be reborn sinless after being cleansed by His blood at salvation when our sin debt is paid! Praise God
#
# OUR beta tokenizer ['user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'He', 'also', 'clarified', 'that', 'there', 'is', 'the', 'water', 'birth', 'when', 'we', 'are', 'physically', 'born', 'Then', 'there', 'is', 'the', 'spiritual', 'birth', 'which', 'is', 'obviously', 'when', 'we', 'spiritually', 'die', 'to', 'our', 'sinful', 'flesh', 'and', 'be', 'reborn', 'sinless', 'after', 'being', 'cleansed', 'by', 'His', 'blood', 'at', 'salvation', 'when', 'our', 'sin', 'debt', 'is', 'paid', 'Praise', 'God']
# DESIRED  tokenizer ['@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', 'He', 'also', 'clarified', 'that', 'there', 'is', 'the', 'water', 'birth', 'when', 'we', 'are', 'physically', 'born', '.', 'Then', 'there', 'is', 'the', 'spiritual', 'birth', 'which', 'is', 'obviously', 'when', 'we', 'spiritually', 'die', 'to', 'our', 'sinful', 'flesh', 'and', 'be', 'reborn', 'sinless', 'after', 'being', 'cleansed', 'by', 'His', 'blood', 'at', 'salvation', 'when', 'our', 'sin', 'debt', 'is', 'paid', '!', 'Praise', 'God']
#
#
# @user @user Why are you wasting time replying on twitter (trolling) on behalf of people making under that amount?  Seems like someone is just a propaganda pusher...or likes gloating to other #MAGA's that they got screwed by Trump.
#
# OUR beta tokenizer ['user', 'user', 'Why', 'are', 'you', 'wasting', 'time', 'replying', 'on', 'twitter', 'trolling', 'on', 'behalf', 'of', 'people', 'making', 'under', 'that', 'amount', 'Seems', 'like', 'someone', 'is', 'just', 'a', 'propaganda', 'pusher', 'or', 'likes', 'gloating', 'to', 'other', 'MAGA', 's', 'that', 'they', 'got', 'screwed', 'by', 'Trump']
# DESIRED  tokenizer ['@user', '@user', 'Why', 'are', 'you', 'wasting', 'time', 'replying', 'on', 'twitter', '(', 'trolling', ')', 'on', 'behalf', 'of', 'people', 'making', 'under', 'that', 'amount', '?', 'Seems', 'like', 'someone', 'is', 'just', 'a', 'propaganda', 'pusher', '...', 'or', 'likes', 'gloating', 'to', 'other', "#MAGA's", 'that', 'they', 'got', 'screwed', 'by', 'Trump', '.']
#
#
# @user We had Leveon Bell. Thats the dumbest argument. But we can compare college for when he played. His best season was 1700 yds 26 TDs. How about Collins? And this is Conners first year starting and he is starting much better than Collins
#
# OUR beta tokenizer ['user', 'We', 'had', 'Leveon', 'Bell', 'Thats', 'the', 'dumbest', 'argument', 'But', 'we', 'can', 'compare', 'college', 'for', 'when', 'he', 'played', 'His', 'best', 'season', 'was', '1700', 'yds', '26', 'TDs', 'How', 'about', 'Collins', 'And', 'this', 'is', 'Conners', 'first', 'year', 'starting', 'and', 'he', 'is', 'starting', 'much', 'better', 'than', 'Collins']
# DESIRED  tokenizer ['@user', 'We', 'had', 'Leveon', 'Bell', '.', 'Thats', 'the', 'dumbest', 'argument', '.', 'But', 'we', 'can', 'compare', 'college', 'for', 'when', 'he', 'played', '.', 'His', 'best', 'season', 'was', '1700', 'yds', '26', 'TDs', '.', 'How', 'about', 'Collins', '?', 'And', 'this', 'is', 'Conners', 'first', 'year', 'starting', 'and', 'he', 'is', 'starting', 'much', 'better', 'than', 'Collins']
#
#
# @user @user SHE IS A FUCKING MESS!! I HATE HER SO MUCH
#
# OUR beta tokenizer ['user', 'user', 'SHE', 'IS', 'A', 'FUCKING', 'MESS', 'I', 'HATE', 'HER', 'SO', 'MUCH']
# DESIRED  tokenizer ['@user', '@user', 'SHE', 'IS', 'A', 'FUCKING', 'MESS', '!', '!', 'I', 'HATE', 'HER', 'SO', 'MUCH']
#
#
# @user He is so underrated and I love how pure he is as a person
#
# OUR beta tokenizer ['user', 'He', 'is', 'so', 'underrated', 'and', 'I', 'love', 'how', 'pure', 'he', 'is', 'as', 'a', 'person']
# DESIRED  tokenizer ['@user', 'He', 'is', 'so', 'underrated', 'and', 'I', 'love', 'how', 'pure', 'he', 'is', 'as', 'a', 'person']
#
#
# @user Haha we set then 😂
#
# OUR beta tokenizer ['user', 'Haha', 'we', 'set', 'then']
# DESIRED  tokenizer ['@user', 'Haha', 'we', 'set', 'then', '😂']
#
#
# @user he is a psychic ain’t he
#
# OUR beta tokenizer ['user', 'he', 'is', 'a', 'psychic', 'ain', 't', 'he']
# DESIRED  tokenizer ['@user', 'he', 'is', 'a', 'psychic', 'ain', '’', 't', 'he']
#
#
# @user I was think she jisoo but I’m Focused I found she is taeyoun
#
# OUR beta tokenizer ['user', 'I', 'was', 'think', 'she', 'jisoo', 'but', 'I', 'm', 'Focused', 'I', 'found', 'she', 'is', 'taeyoun']
# DESIRED  tokenizer ['@user', 'I', 'was', 'think', 'she', 'jisoo', 'but', 'I', '’', 'm', 'Focused', 'I', 'found', 'she', 'is', 'taeyoun']
#
#
# @user I am stunned that you are giving this guy airtime. Stunned.
#
# OUR beta tokenizer ['user', 'I', 'am', 'stunned', 'that', 'you', 'are', 'giving', 'this', 'guy', 'airtime', 'Stunned']
# DESIRED  tokenizer ['@user', 'I', 'am', 'stunned', 'that', 'you', 'are', 'giving', 'this', 'guy', 'airtime', '.', 'Stunned', '.']
#
#
# @user She Wants Gun Control? Figures
#
# OUR beta tokenizer ['user', 'She', 'Wants', 'Gun', 'Control', 'Figures']
# DESIRED  tokenizer ['@user', 'She', 'Wants', 'Gun', 'Control', '?', 'Figures']
#
#
# @user @user @user Didn't see him matching with antifa tbh
#
# OUR beta tokenizer ['user', 'user', 'user', 'Didn', 't', 'see', 'him', 'matching', 'with', 'antifa', 'tbh']
# DESIRED  tokenizer ['@user', '@user', '@user', "Didn't", 'see', 'him', 'matching', 'with', 'antifa', 'tbh']
#
#
# @user @user @user And conservatives are no longer conservatives why do you think Maxime Bernier has started a new party that will follow original Conservative values.
#
# OUR beta tokenizer ['user', 'user', 'user', 'And', 'conservatives', 'are', 'no', 'longer', 'conservatives', 'why', 'do', 'you', 'think', 'Maxime', 'Bernier', 'has', 'started', 'a', 'new', 'party', 'that', 'will', 'follow', 'original', 'Conservative', 'values']
# DESIRED  tokenizer ['@user', '@user', '@user', 'And', 'conservatives', 'are', 'no', 'longer', 'conservatives', 'why', 'do', 'you', 'think', 'Maxime', 'Bernier', 'has', 'started', 'a', 'new', 'party', 'that', 'will', 'follow', 'original', 'Conservative', 'values', '.']
#
#
# @user Holy shit I love her???
#
# OUR beta tokenizer ['user', 'Holy', 'shit', 'I', 'love', 'her']
# DESIRED  tokenizer ['@user', 'Holy', 'shit', 'I', 'love', 'her', '?', '?', '?']
#
#
# @user @user @user Can you let him know?
#
# OUR beta tokenizer ['user', 'user', 'user', 'Can', 'you', 'let', 'him', 'know']
# DESIRED  tokenizer ['@user', '@user', '@user', 'Can', 'you', 'let', 'him', 'know', '?']
#
#
# @user @user @user @user @user @user Sir it comes to something when you present a lie as a fact.... Have you no shame? This is the fact 65% of labour voters voted to Remain. Ref YouGov polls. Your position is based on a false premise......have a nice day
#
# OUR beta tokenizer ['user', 'user', 'user', 'user', 'user', 'user', 'Sir', 'it', 'comes', 'to', 'something', 'when', 'you', 'present', 'a', 'lie', 'as', 'a', 'fact', 'Have', 'you', 'no', 'shame', 'This', 'is', 'the', 'fact', '65', 'of', 'labour', 'voters', 'voted', 'to', 'Remain', 'Ref', 'YouGov', 'polls', 'Your', 'position', 'is', 'based', 'on', 'a', 'false', 'premise', 'have', 'a', 'nice', 'day']
# DESIRED  tokenizer ['@user', '@user', '@user', '@user', '@user', '@user', 'Sir', 'it', 'comes', 'to', 'something', 'when', 'you', 'present', 'a', 'lie', 'as', 'a', 'fact', '...', 'Have', 'you', 'no', 'shame', '?', 'This', 'is', 'the', 'fact', '65', '%', 'of', 'labour', 'voters', 'voted', 'to', 'Remain', '.', 'Ref', 'YouGov', 'polls', '.', 'Your', 'position', 'is', 'based', 'on', 'a', 'false', 'premise', '...', 'have', 'a', 'nice', 'day']
#
#
# @user @user A stark reminder that @user and you are trying to con us with chequers and a bit of our waters back - not good enough - @user @user  @user @user @user @user @user @user appeasing is not a good look @user
#
# OUR beta tokenizer ['user', 'user', 'A', 'stark', 'reminder', 'that', 'user', 'and', 'you', 'are', 'trying', 'to', 'con', 'us', 'with', 'chequers', 'and', 'a', 'bit', 'of', 'our', 'waters', 'back', 'not', 'good', 'enough', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'appeasing', 'is', 'not', 'a', 'good', 'look', 'user']
# DESIRED  tokenizer ['@user', '@user', 'A', 'stark', 'reminder', 'that', '@user', 'and', 'you', 'are', 'trying', 'to', 'con', 'us', 'with', 'chequers', 'and', 'a', 'bit', 'of', 'our', 'waters', 'back', '-', 'not', 'good', 'enough', '-', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', 'appeasing', 'is', 'not', 'a', 'good', 'look', '@user']
#
#
# @user @user WHERE'S holier than thou @user  Sippin wine in the shade somewhere...  #MAGA
#
# OUR beta tokenizer ['user', 'user', 'WHERE', 'S', 'holier', 'than', 'thou', 'user', 'Sippin', 'wine', 'in', 'the', 'shade', 'somewhere', 'MAGA']
# DESIRED  tokenizer ['@user', '@user', "WHERE'S", 'holier', 'than', 'thou', '@user', 'Sippin', 'wine', 'in', 'the', 'shade', 'somewhere', '...', '#MAGA']
#
#
# @user I can’t cuz that nigga retarded smh
#
# OUR beta tokenizer ['user', 'I', 'can', 't', 'cuz', 'that', 'nigga', 'retarded', 'smh']
# DESIRED  tokenizer ['@user', 'I', 'can', '’', 't', 'cuz', 'that', 'nigga', 'retarded', 'smh']
#
#
# 9 factory workers gunned down in Iowa City with 20-gauge Winchester pump-action shotgun. The NRA blames gun control laws.
#
# OUR beta tokenizer ['9', 'factory', 'workers', 'gunned', 'down', 'in', 'Iowa', 'City', 'with', '20', 'gauge', 'Winchester', 'pump', 'action', 'shotgun', 'The', 'NRA', 'blames', 'gun', 'control', 'laws']
# DESIRED  tokenizer ['9', 'factory', 'workers', 'gunned', 'down', 'in', 'Iowa', 'City', 'with', '20', '-', 'gauge', 'Winchester', 'pump-action', 'shotgun', '.', 'The', 'NRA', 'blames', 'gun', 'control', 'laws', '.']
#
#
# @user So the overwhelming liberals in the populated states can make policy for the rest of America with whom they have no clue about.  Just because California has the biggest population does not mean the U.S. shares in their values.  Get a clue Hillary.
#
# OUR beta tokenizer ['user', 'So', 'the', 'overwhelming', 'liberals', 'in', 'the', 'populated', 'states', 'can', 'make', 'policy', 'for', 'the', 'rest', 'of', 'America', 'with', 'whom', 'they', 'have', 'no', 'clue', 'about', 'Just', 'because', 'California', 'has', 'the', 'biggest', 'population', 'does', 'not', 'mean', 'the', 'U', 'S', 'shares', 'in', 'their', 'values', 'Get', 'a', 'clue', 'Hillary']
# DESIRED  tokenizer ['@user', 'So', 'the', 'overwhelming', 'liberals', 'in', 'the', 'populated', 'states', 'can', 'make', 'policy', 'for', 'the', 'rest', 'of', 'America', 'with', 'whom', 'they', 'have', 'no', 'clue', 'about', '.', 'Just', 'because', 'California', 'has', 'the', 'biggest', 'population', 'does', 'not', 'mean', 'the', 'U', '.', 'S', '.', 'shares', 'in', 'their', 'values', '.', 'Get', 'a', 'clue', 'Hillary', '.']
#
#
# @user Berkeley Antifa do not agree with you
#
# OUR beta tokenizer ['user', 'Berkeley', 'Antifa', 'do', 'not', 'agree', 'with', 'you']
# DESIRED  tokenizer ['@user', 'Berkeley', 'Antifa', 'do', 'not', 'agree', 'with', 'you']
#
#
# @user He is quite good at faking. Must have done it numerous times
#
# OUR beta tokenizer ['user', 'He', 'is', 'quite', 'good', 'at', 'faking', 'Must', 'have', 'done', 'it', 'numerous', 'times']
# DESIRED  tokenizer ['@user', 'He', 'is', 'quite', 'good', 'at', 'faking', '.', 'Must', 'have', 'done', 'it', 'numerous', 'times']
#
#
# @user Griexsevia
#
# OUR beta tokenizer ['user', 'Griexsevia']
# DESIRED  tokenizer ['@user', 'Griexsevia']
#
#
# @user We do have a few outages reported in Toronto.   Here's a link to our outage map to see if you are in one of the defined spots - -SC
#
# OUR beta tokenizer ['user', 'We', 'do', 'have', 'a', 'few', 'outages', 'reported', 'in', 'Toronto', 'Here', 's', 'a', 'link', 'to', 'our', 'outage', 'map', 'to', 'see', 'if', 'you', 'are', 'in', 'one', 'of', 'the', 'defined', 'spots', 'SC']
# DESIRED  tokenizer ['@user', 'We', 'do', 'have', 'a', 'few', 'outages', 'reported', 'in', 'Toronto', '.', "Here's", 'a', 'link', 'to', 'our', 'outage', 'map', 'to', 'see', 'if', 'you', 'are', 'in', 'one', 'of', 'the', 'defined', 'spots', '-', '-', 'SC']
#
#
# @user @user What new gun control laws would you like to see passed and what would they accomplish?
#
# OUR beta tokenizer ['user', 'user', 'What', 'new', 'gun', 'control', 'laws', 'would', 'you', 'like', 'to', 'see', 'passed', 'and', 'what', 'would', 'they', 'accomplish']
# DESIRED  tokenizer ['@user', '@user', 'What', 'new', 'gun', 'control', 'laws', 'would', 'you', 'like', 'to', 'see', 'passed', 'and', 'what', 'would', 'they', 'accomplish', '?']
#
#
# Take Take Take #WalkAway from the #idiot party! #MAGA
#
# OUR beta tokenizer ['Take', 'Take', 'Take', 'WalkAway', 'from', 'the', 'idiot', 'party', 'MAGA']
# DESIRED  tokenizer ['Take', 'Take', 'Take', '#WalkAway', 'from', 'the', '#idiot', 'party', '!', '#MAGA']
#
#
# @user @user You are so correct the Democratic party for slavery and pro-nazi gun control
#
# OUR beta tokenizer ['user', 'user', 'You', 'are', 'so', 'correct', 'the', 'Democratic', 'party', 'for', 'slavery', 'and', 'pro', 'nazi', 'gun', 'control']
# DESIRED  tokenizer ['@user', '@user', 'You', 'are', 'so', 'correct', 'the', 'Democratic', 'party', 'for', 'slavery', 'and', 'pro-nazi', 'gun', 'control']
#
#
# @user Good luck
#
# OUR beta tokenizer ['user', 'Good', 'luck']
# DESIRED  tokenizer ['@user', 'Good', 'luck']
#
#
# @user @user @user She did it and she is alive is greatness of Hinduism. You should try it with Quran if you have guts.
#
# OUR beta tokenizer ['user', 'user', 'user', 'She', 'did', 'it', 'and', 'she', 'is', 'alive', 'is', 'greatness', 'of', 'Hinduism', 'You', 'should', 'try', 'it', 'with', 'Quran', 'if', 'you', 'have', 'guts']
# DESIRED  tokenizer ['@user', '@user', '@user', 'She', 'did', 'it', 'and', 'she', 'is', 'alive', 'is', 'greatness', 'of', 'Hinduism', '.', 'You', 'should', 'try', 'it', 'with', 'Quran', 'if', 'you', 'have', 'guts', '.']
#
#
# @user Hell ya
#
# OUR beta tokenizer ['user', 'Hell', 'ya']
# DESIRED  tokenizer ['@user', 'Hell', 'ya']
#
#
# @user @user Prove your claim or be exposed as the lying piece of shit you are.   Meanwhile...
#
# OUR beta tokenizer ['user', 'user', 'Prove', 'your', 'claim', 'or', 'be', 'exposed', 'as', 'the', 'lying', 'piece', 'of', 'shit', 'you', 'are', 'Meanwhile']
# DESIRED  tokenizer ['@user', '@user', 'Prove', 'your', 'claim', 'or', 'be', 'exposed', 'as', 'the', 'lying', 'piece', 'of', 'shit', 'you', 'are', '.', 'Meanwhile', '...']
#
#
# @user Get shit poppin
#
# OUR beta tokenizer ['user', 'Get', 'shit', 'poppin']
# DESIRED  tokenizer ['@user', 'Get', 'shit', 'poppin']
#
#
# @user She says no. You are now sad. She then realizes what you might actually mean. She slaps you. She says no. Now you are sad AND your face hurts.
#
# OUR beta tokenizer ['user', 'She', 'says', 'no', 'You', 'are', 'now', 'sad', 'She', 'then', 'realizes', 'what', 'you', 'might', 'actually', 'mean', 'She', 'slaps', 'you', 'She', 'says', 'no', 'Now', 'you', 'are', 'sad', 'AND', 'your', 'face', 'hurts']
# DESIRED  tokenizer ['@user', 'She', 'says', 'no', '.', 'You', 'are', 'now', 'sad', '.', 'She', 'then', 'realizes', 'what', 'you', 'might', 'actually', 'mean', '.', 'She', 'slaps', 'you', '.', 'She', 'says', 'no', '.', 'Now', 'you', 'are', 'sad', 'AND', 'your', 'face', 'hurts', '.']
#
#
# @user Patrick ass??
#
# OUR beta tokenizer ['user', 'Patrick', 'ass']
# DESIRED  tokenizer ['@user', 'Patrick', 'ass', '?', '?']
#
#
# @user Eric Holder should've been in his 2nd yr at Gitmo. What's the update on Gitmo's expansion?  Why is he still breathing in our freedom air?
#
# OUR beta tokenizer ['user', 'Eric', 'Holder', 'should', 've', 'been', 'in', 'his', '2nd', 'yr', 'at', 'Gitmo', 'What', 's', 'the', 'update', 'on', 'Gitmo', 's', 'expansion', 'Why', 'is', 'he', 'still', 'breathing', 'in', 'our', 'freedom', 'air']
# DESIRED  tokenizer ['@user', 'Eric', 'Holder', "should've", 'been', 'in', 'his', '2nd', 'yr', 'at', 'Gitmo', '.', "What's", 'the', 'update', 'on', "Gitmo's", 'expansion', '?', 'Why', 'is', 'he', 'still', 'breathing', 'in', 'our', 'freedom', 'air', '?']
#
#
# @user All we ever hear from Hillary is beeching &amp; moaning.  Dang ! That witch never get tired of complaining!
#
# OUR beta tokenizer ['user', 'All', 'we', 'ever', 'hear', 'from', 'Hillary', 'is', 'beeching', 'amp', 'moaning', 'Dang', 'That', 'witch', 'never', 'get', 'tired', 'of', 'complaining']
# DESIRED  tokenizer ['@user', 'All', 'we', 'ever', 'hear', 'from', 'Hillary', 'is', 'beeching', '&', 'moaning', '.', 'Dang', '!', 'That', 'witch', 'never', 'get', 'tired', 'of', 'complaining', '!']
#
#
# @user Buy one
#
# OUR beta tokenizer ['user', 'Buy', 'one']
# DESIRED  tokenizer ['@user', 'Buy', 'one']
#
#
# @user Come on CNN.  He literally introduced himself.  The guy is a public figure for gun control.  Call him out!
#
# OUR beta tokenizer ['user', 'Come', 'on', 'CNN', 'He', 'literally', 'introduced', 'himself', 'The', 'guy', 'is', 'a', 'public', 'figure', 'for', 'gun', 'control', 'Call', 'him', 'out']
# DESIRED  tokenizer ['@user', 'Come', 'on', 'CNN', '.', 'He', 'literally', 'introduced', 'himself', '.', 'The', 'guy', 'is', 'a', 'public', 'figure', 'for', 'gun', 'control', '.', 'Call', 'him', 'out', '!']
#
#
# @user @user I didn't know Oprah Winfrey knew how to play tennis. .. 😱
#
# OUR beta tokenizer ['user', 'user', 'I', 'didn', 't', 'know', 'Oprah', 'Winfrey', 'knew', 'how', 'to', 'play', 'tennis']
# DESIRED  tokenizer ['@user', '@user', 'I', "didn't", 'know', 'Oprah', 'Winfrey', 'knew', 'how', 'to', 'play', 'tennis', '. ..', '😱']
#
#
# @user Yeah she is
#
# OUR beta tokenizer ['user', 'Yeah', 'she', 'is']
# DESIRED  tokenizer ['@user', 'Yeah', 'she', 'is']
#
#
# @user @user @user She is a walking talking lie..  that’s why.
#
# OUR beta tokenizer ['user', 'user', 'user', 'She', 'is', 'a', 'walking', 'talking', 'lie', 'that', 's', 'why']
# DESIRED  tokenizer ['@user', '@user', '@user', 'She', 'is', 'a', 'walking', 'talking', 'lie', '..', 'that', '’', 's', 'why', '.']
#
#
# @user She is so cute ♡
#
# OUR beta tokenizer ['user', 'She', 'is', 'so', 'cute']
# DESIRED  tokenizer ['@user', 'She', 'is', 'so', 'cute', '♡']
#
#
# @user Holder is responsible for selling guns to the Mexican cartel. Just another Obama administration law breaker.
#
# OUR beta tokenizer ['user', 'Holder', 'is', 'responsible', 'for', 'selling', 'guns', 'to', 'the', 'Mexican', 'cartel', 'Just', 'another', 'Obama', 'administration', 'law', 'breaker']
# DESIRED  tokenizer ['@user', 'Holder', 'is', 'responsible', 'for', 'selling', 'guns', 'to', 'the', 'Mexican', 'cartel', '.', 'Just', 'another', 'Obama', 'administration', 'law', 'breaker', '.']
#
#
# @user @user Sounds to me like the Pope needs counselled on confession.
#
# OUR beta tokenizer ['user', 'user', 'Sounds', 'to', 'me', 'like', 'the', 'Pope', 'needs', 'counselled', 'on', 'confession']
# DESIRED  tokenizer ['@user', '@user', 'Sounds', 'to', 'me', 'like', 'the', 'Pope', 'needs', 'counselled', 'on', 'confession', '.']
#
#
# @user Better than what? Truth? Politicians have never been good at that. My America is better than Flake.
#
# OUR beta tokenizer ['user', 'Better', 'than', 'what', 'Truth', 'Politicians', 'have', 'never', 'been', 'good', 'at', 'that', 'My', 'America', 'is', 'better', 'than', 'Flake']
# DESIRED  tokenizer ['@user', 'Better', 'than', 'what', '?', 'Truth', '?', 'Politicians', 'have', 'never', 'been', 'good', 'at', 'that', '.', 'My', 'America', 'is', 'better', 'than', 'Flake', '.']
#
#
# @user @user That so many “thoughtful conservatives” who rushed to Kavanaugh’s defense didn’t consider  their own statements re: black teenagers tells you everything about how “thoughtful” they truly are.
#
# OUR beta tokenizer ['user', 'user', 'That', 'so', 'many', 'thoughtful', 'conservatives', 'who', 'rushed', 'to', 'Kavanaugh', 's', 'defense', 'didn', 't', 'consider', 'their', 'own', 'statements', 're', 'black', 'teenagers', 'tells', 'you', 'everything', 'about', 'how', 'thoughtful', 'they', 'truly', 'are']
# DESIRED  tokenizer ['@user', '@user', 'That', 'so', 'many', '“', 'thoughtful', 'conservatives', '”', 'who', 'rushed', 'to', 'Kavanaugh', '’', 's', 'defense', 'didn', '’', 't', 'consider', 'their', 'own', 'statements', 're', ':', 'black', 'teenagers', 'tells', 'you', 'everything', 'about', 'how', '“', 'thoughtful', '”', 'they', 'truly', 'are', '.']
#
#
# @user you couldn’t catch me letting some saggy whitey bitch talkin like this to me 😫 bitch eat dirt
#
# OUR beta tokenizer ['user', 'you', 'couldn', 't', 'catch', 'me', 'letting', 'some', 'saggy', 'whitey', 'bitch', 'talkin', 'like', 'this', 'to', 'me', 'bitch', 'eat', 'dirt']
# DESIRED  tokenizer ['@user', 'you', 'couldn', '’', 't', 'catch', 'me', 'letting', 'some', 'saggy', 'whitey', 'bitch', 'talkin', 'like', 'this', 'to', 'me', '😫', 'bitch', 'eat', 'dirt']
#
#
# .@USER  joined the show to talk about how she is leading the fight against breast cancer at @user @user Listen to the full interview:
#
# OUR beta tokenizer ['USER', 'joined', 'the', 'show', 'to', 'talk', 'about', 'how', 'she', 'is', 'leading', 'the', 'fight', 'against', 'breast', 'cancer', 'at', 'user', 'user', 'Listen', 'to', 'the', 'full', 'interview']
# DESIRED  tokenizer ['.', '@USER', 'joined', 'the', 'show', 'to', 'talk', 'about', 'how', 'she', 'is', 'leading', 'the', 'fight', 'against', 'breast', 'cancer', 'at', '@user', '@user', 'Listen', 'to', 'the', 'full', 'interview', ':']
#
#
# @user You are becoming the court jester of the senate
#
# OUR beta tokenizer ['user', 'You', 'are', 'becoming', 'the', 'court', 'jester', 'of', 'the', 'senate']
# DESIRED  tokenizer ['@user', 'You', 'are', 'becoming', 'the', 'court', 'jester', 'of', 'the', 'senate']
#
#
# @user tell that to him. He is very perfectionist. I don’t think we will change that ever 😅
#
# OUR beta tokenizer ['user', 'tell', 'that', 'to', 'him', 'He', 'is', 'very', 'perfectionist', 'I', 'don', 't', 'think', 'we', 'will', 'change', 'that', 'ever']
# DESIRED  tokenizer ['@user', 'tell', 'that', 'to', 'him', '.', 'He', 'is', 'very', 'perfectionist', '.', 'I', 'don', '’', 't', 'think', 'we', 'will', 'change', 'that', 'ever', '😅']
#
#
# @user @user @user @user Also there to help banks boost their balance sheets post crash. I'd imagine atleast 15% (Maybe more) of current house prices are part of the bank bailout package.
#
# OUR beta tokenizer ['user', 'user', 'user', 'user', 'Also', 'there', 'to', 'help', 'banks', 'boost', 'their', 'balance', 'sheets', 'post', 'crash', 'I', 'd', 'imagine', 'atleast', '15', 'Maybe', 'more', 'of', 'current', 'house', 'prices', 'are', 'part', 'of', 'the', 'bank', 'bailout', 'package']
# DESIRED  tokenizer ['@user', '@user', '@user', '@user', 'Also', 'there', 'to', 'help', 'banks', 'boost', 'their', 'balance', 'sheets', 'post', 'crash', '.', "I'd", 'imagine', 'atleast', '15', '%', '(', 'Maybe', 'more', ')', 'of', 'current', 'house', 'prices', 'are', 'part', 'of', 'the', 'bank', 'bailout', 'package', '.']
#
#
# @user He’s a DA. Someone educate him he’s in the South now
#
# OUR beta tokenizer ['user', 'He', 's', 'a', 'DA', 'Someone', 'educate', 'him', 'he', 's', 'in', 'the', 'South', 'now']
# DESIRED  tokenizer ['@user', 'He', '’', 's', 'a', 'DA', '.', 'Someone', 'educate', 'him', 'he', '’', 's', 'in', 'the', 'South', 'now']
#
#
# @user Notice how everyone avoids this tweet ☝️☝️  They might think you are referring to them. 😂😂  But not me comrade. I stalk everyone. 🤟🤟
#
# OUR beta tokenizer ['user', 'Notice', 'how', 'everyone', 'avoids', 'this', 'tweet', 'They', 'might', 'think', 'you', 'are', 'referring', 'to', 'them', 'But', 'not', 'me', 'comrade', 'I', 'stalk', 'everyone']
# DESIRED  tokenizer ['@user', 'Notice', 'how', 'everyone', 'avoids', 'this', 'tweet', '☝', '️', '☝', '️', 'They', 'might', 'think', 'you', 'are', 'referring', 'to', 'them', '.', '😂', '😂', 'But', 'not', 'me', 'comrade', '.', 'I', 'stalk', 'everyone', '.', '🤟', '🤟']
#
#
# @user I don't know if this cat even realizes what he is doing.
#
# OUR beta tokenizer ['user', 'I', 'don', 't', 'know', 'if', 'this', 'cat', 'even', 'realizes', 'what', 'he', 'is', 'doing']
# DESIRED  tokenizer ['@user', 'I', "don't", 'know', 'if', 'this', 'cat', 'even', 'realizes', 'what', 'he', 'is', 'doing', '.']
#
#
# @user @user He is.
#
# OUR beta tokenizer ['user', 'user', 'He', 'is']
# DESIRED  tokenizer ['@user', '@user', 'He', 'is', '.']
#
#
# @user And you are a football fan too !
#
# OUR beta tokenizer ['user', 'And', 'you', 'are', 'a', 'football', 'fan', 'too']
# DESIRED  tokenizer ['@user', 'And', 'you', 'are', 'a', 'football', 'fan', 'too', '!']
#
#
# @user Well he’s closer to Lincoln than you are.
#
# OUR beta tokenizer ['user', 'Well', 'he', 's', 'closer', 'to', 'Lincoln', 'than', 'you', 'are']
# DESIRED  tokenizer ['@user', 'Well', 'he', '’', 's', 'closer', 'to', 'Lincoln', 'than', 'you', 'are', '.']
#
#
# @user Every one of them is more rank than she is. And she's pretty rank. So I guess they all outrank her...
#
# OUR beta tokenizer ['user', 'Every', 'one', 'of', 'them', 'is', 'more', 'rank', 'than', 'she', 'is', 'And', 'she', 's', 'pretty', 'rank', 'So', 'I', 'guess', 'they', 'all', 'outrank', 'her']
# DESIRED  tokenizer ['@user', 'Every', 'one', 'of', 'them', 'is', 'more', 'rank', 'than', 'she', 'is', '.', 'And', "she's", 'pretty', 'rank', '.', 'So', 'I', 'guess', 'they', 'all', 'outrank', 'her', '...']
#
#
# @user well...?
#
# OUR beta tokenizer ['user', 'well']
# DESIRED  tokenizer ['@user', 'well', '...', '?']
#
#
# @user And why report this garbage.  We don't give a crap.
#
# OUR beta tokenizer ['user', 'And', 'why', 'report', 'this', 'garbage', 'We', 'don', 't', 'give', 'a', 'crap']
# DESIRED  tokenizer ['@user', 'And', 'why', 'report', 'this', 'garbage', '.', 'We', "don't", 'give', 'a', 'crap', '.']
#
#
# @user @user @user Says one of the thickest cultists on Twitter. Irony at its finest.
#
# OUR beta tokenizer ['user', 'user', 'user', 'Says', 'one', 'of', 'the', 'thickest', 'cultists', 'on', 'Twitter', 'Irony', 'at', 'its', 'finest']
# DESIRED  tokenizer ['@user', '@user', '@user', 'Says', 'one', 'of', 'the', 'thickest', 'cultists', 'on', 'Twitter', '.', 'Irony', 'at', 'its', 'finest', '.']
#
#
# @user She is disgusting
#
# OUR beta tokenizer ['user', 'She', 'is', 'disgusting']
# DESIRED  tokenizer ['@user', 'She', 'is', 'disgusting']
#
#
# @user Eric holder is Obama's straw man of corruption
#
# OUR beta tokenizer ['user', 'Eric', 'holder', 'is', 'Obama', 's', 'straw', 'man', 'of', 'corruption']
# DESIRED  tokenizer ['@user', 'Eric', 'holder', 'is', "Obama's", 'straw', 'man', 'of', 'corruption']
#
#
# @user And yes your presidency was one of the absolute worst. Go back to that....no way.
#
# OUR beta tokenizer ['user', 'And', 'yes', 'your', 'presidency', 'was', 'one', 'of', 'the', 'absolute', 'worst', 'Go', 'back', 'to', 'that', 'no', 'way']
# DESIRED  tokenizer ['@user', 'And', 'yes', 'your', 'presidency', 'was', 'one', 'of', 'the', 'absolute', 'worst', '.', 'Go', 'back', 'to', 'that', '...', 'no', 'way', '.']
#
#
# @user @user @user You should take this picture down you destroyed one of my all time favorite Comedian/Actors @user
#
# OUR beta tokenizer ['user', 'user', 'user', 'You', 'should', 'take', 'this', 'picture', 'down', 'you', 'destroyed', 'one', 'of', 'my', 'all', 'time', 'favorite', 'Comedian', 'Actors', 'user']
# DESIRED  tokenizer ['@user', '@user', '@user', 'You', 'should', 'take', 'this', 'picture', 'down', 'you', 'destroyed', 'one', 'of', 'my', 'all', 'time', 'favorite', 'Comedian', '/', 'Actors', '@user']
#
#
# @user @user @user @user @user @user I saw her in Denver last week. She is still traumatized. Cohen owes her so much because of 'My Life on the D List'.
#
# OUR beta tokenizer ['user', 'user', 'user', 'user', 'user', 'user', 'I', 'saw', 'her', 'in', 'Denver', 'last', 'week', 'She', 'is', 'still', 'traumatized', 'Cohen', 'owes', 'her', 'so', 'much', 'because', 'of', 'My', 'Life', 'on', 'the', 'D', 'List']
# DESIRED  tokenizer ['@user', '@user', '@user', '@user', '@user', '@user', 'I', 'saw', 'her', 'in', 'Denver', 'last', 'week', '.', 'She', 'is', 'still', 'traumatized', '.', 'Cohen', 'owes', 'her', 'so', 'much', 'because', 'of', "'", 'My', 'Life', 'on', 'the', 'D', 'List', "'", '.']
#
#
# @user America is better than swamp crud like YOU!
#
# OUR beta tokenizer ['user', 'America', 'is', 'better', 'than', 'swamp', 'crud', 'like', 'YOU']
# DESIRED  tokenizer ['@user', 'America', 'is', 'better', 'than', 'swamp', 'crud', 'like', 'YOU', '!']
#
#
# @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user Thank you for adding me Razor!  Patriots- if you aren’t following my Primary account @user - will you take a minute &amp; Follow me? Thanks &amp; MAGA🇺🇸
#
# OUR beta tokenizer ['user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'Thank', 'you', 'for', 'adding', 'me', 'Razor', 'Patriots', 'if', 'you', 'aren', 't', 'following', 'my', 'Primary', 'account', 'user', 'will', 'you', 'take', 'a', 'minute', 'amp', 'Follow', 'me', 'Thanks', 'amp', 'MAGA']
# DESIRED  tokenizer ['@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', 'Thank', 'you', 'for', 'adding', 'me', 'Razor', '!', 'Patriots', '-', 'if', 'you', 'aren', '’', 't', 'following', 'my', 'Primary', 'account', '@user', '-', 'will', 'you', 'take', 'a', 'minute', '&', 'Follow', 'me', '?', 'Thanks', '&', 'MAGA', '🇺', '🇸']
#
#
# @user The lies i keep hearing everyday sigh *INHALES* IM TIRED OF YOU PUTTING YOURSELF DOWN AND IF PPL DONT SEE HOW BEAUTIFUL MY BESTFRIEND IS THEN ITS THEIR PROBLEM You are beautiful ive seen iT so its my place to tell you you are beautiful and i accept nothing less. If not more 😤
#
# OUR beta tokenizer ['user', 'The', 'lies', 'i', 'keep', 'hearing', 'everyday', 'sigh', 'INHALES', 'IM', 'TIRED', 'OF', 'YOU', 'PUTTING', 'YOURSELF', 'DOWN', 'AND', 'IF', 'PPL', 'DONT', 'SEE', 'HOW', 'BEAUTIFUL', 'MY', 'BESTFRIEND', 'IS', 'THEN', 'ITS', 'THEIR', 'PROBLEM', 'You', 'are', 'beautiful', 'ive', 'seen', 'iT', 'so', 'its', 'my', 'place', 'to', 'tell', 'you', 'you', 'are', 'beautiful', 'and', 'i', 'accept', 'nothing', 'less', 'If', 'not', 'more']
# DESIRED  tokenizer ['@user', 'The', 'lies', 'i', 'keep', 'hearing', 'everyday', 'sigh', '*', 'INHALES', '*', 'IM', 'TIRED', 'OF', 'YOU', 'PUTTING', 'YOURSELF', 'DOWN', 'AND', 'IF', 'PPL', 'DONT', 'SEE', 'HOW', 'BEAUTIFUL', 'MY', 'BESTFRIEND', 'IS', 'THEN', 'ITS', 'THEIR', 'PROBLEM', 'You', 'are', 'beautiful', 'ive', 'seen', 'iT', 'so', 'its', 'my', 'place', 'to', 'tell', 'you', 'you', 'are', 'beautiful', 'and', 'i', 'accept', 'nothing', 'less', '.', 'If', 'not', 'more', '😤']
#
#
# @user He is very perceptive Sweetie!
#
# OUR beta tokenizer ['user', 'He', 'is', 'very', 'perceptive', 'Sweetie']
# DESIRED  tokenizer ['@user', 'He', 'is', 'very', 'perceptive', 'Sweetie', '!']
#
#
# @user Dear Paul McFartney-  You had us at Beatles.  You lost us at President Mad Captain.  Burn in hell-  Jon.""
#
# OUR beta tokenizer ['user', 'Dear', 'Paul', 'McFartney', 'You', 'had', 'us', 'at', 'Beatles', 'You', 'lost', 'us', 'at', 'President', 'Mad', 'Captain', 'Burn', 'in', 'hell', 'Jon']
# DESIRED  tokenizer ['@user', 'Dear', 'Paul', 'McFartney', '-', 'You', 'had', 'us', 'at', 'Beatles', '.', 'You', 'lost', 'us', 'at', 'President', 'Mad', 'Captain', '.', 'Burn', 'in', 'hell', '-', 'Jon', '.', '"', '"']
#
#
# @user you are also the king of taste
#
# OUR beta tokenizer ['user', 'you', 'are', 'also', 'the', 'king', 'of', 'taste']
# DESIRED  tokenizer ['@user', 'you', 'are', 'also', 'the', 'king', 'of', 'taste']
#
#
# @user And everyone knows that Kerry doesn't have a clue!  Heard that from numerous anonymous"" sources who also say he is not sane.  That's what the sources say.""
#
# OUR beta tokenizer ['user', 'And', 'everyone', 'knows', 'that', 'Kerry', 'doesn', 't', 'have', 'a', 'clue', 'Heard', 'that', 'from', 'numerous', 'anonymous', 'sources', 'who', 'also', 'say', 'he', 'is', 'not', 'sane', 'That', 's', 'what', 'the', 'sources', 'say']
# DESIRED  tokenizer ['@user', 'And', 'everyone', 'knows', 'that', 'Kerry', "doesn't", 'have', 'a', 'clue', '!', 'Heard', 'that', 'from', 'numerous', 'anonymous', '"', '"', 'sources', 'who', 'also', 'say', 'he', 'is', 'not', 'sane', '.', "That's", 'what', 'the', 'sources', 'say', '.', '"', '"']
#
#
# @user @user I think she is a hypocrite and loyal to the evil GOP. Vote her out.
#
# OUR beta tokenizer ['user', 'user', 'I', 'think', 'she', 'is', 'a', 'hypocrite', 'and', 'loyal', 'to', 'the', 'evil', 'GOP', 'Vote', 'her', 'out']
# DESIRED  tokenizer ['@user', '@user', 'I', 'think', 'she', 'is', 'a', 'hypocrite', 'and', 'loyal', 'to', 'the', 'evil', 'GOP', '.', 'Vote', 'her', 'out', '.']
#
#
# @user @user Bill Clinton enjoyed raping them while Ted Kennedy enjoyed killing them. But you are cool with that.
#
# OUR beta tokenizer ['user', 'user', 'Bill', 'Clinton', 'enjoyed', 'raping', 'them', 'while', 'Ted', 'Kennedy', 'enjoyed', 'killing', 'them', 'But', 'you', 'are', 'cool', 'with', 'that']
# DESIRED  tokenizer ['@user', '@user', 'Bill', 'Clinton', 'enjoyed', 'raping', 'them', 'while', 'Ted', 'Kennedy', 'enjoyed', 'killing', 'them', '.', 'But', 'you', 'are', 'cool', 'with', 'that', '.']
#
#
# @user #Conservatives #Republicans are #TRAITORS to #America
#
# OUR beta tokenizer ['user', 'Conservatives', 'Republicans', 'are', 'TRAITORS', 'to', 'America']
# DESIRED  tokenizer ['@user', '#Conservatives', '#Republicans', 'are', '#TRAITORS', 'to', '#America']
#
#
# @user This liberal is pissed that anyone would give that disgusting pos an award for equality. And....f.u. for including all liberals in this bullshit decision by the HRC.
#
# OUR beta tokenizer ['user', 'This', 'liberal', 'is', 'pissed', 'that', 'anyone', 'would', 'give', 'that', 'disgusting', 'pos', 'an', 'award', 'for', 'equality', 'And', 'f', 'u', 'for', 'including', 'all', 'liberals', 'in', 'this', 'bullshit', 'decision', 'by', 'the', 'HRC']
# DESIRED  tokenizer ['@user', 'This', 'liberal', 'is', 'pissed', 'that', 'anyone', 'would', 'give', 'that', 'disgusting', 'pos', 'an', 'award', 'for', 'equality', '.', 'And', '...', 'f', '.', 'u', '.', 'for', 'including', 'all', 'liberals', 'in', 'this', 'bullshit', 'decision', 'by', 'the', 'HRC', '.']
#
#
# @user Eirc Holder: a friken idiot
#
# OUR beta tokenizer ['user', 'Eirc', 'Holder', 'a', 'friken', 'idiot']
# DESIRED  tokenizer ['@user', 'Eirc', 'Holder', ':', 'a', 'friken', 'idiot']
#
#
# @user @user You are very beautifull
#
# OUR beta tokenizer ['user', 'user', 'You', 'are', 'very', 'beautifull']
# DESIRED  tokenizer ['@user', '@user', 'You', 'are', 'very', 'beautifull']
#
#
# @user Crazy freaking liberals
#
# OUR beta tokenizer ['user', 'Crazy', 'freaking', 'liberals']
# DESIRED  tokenizer ['@user', 'Crazy', 'freaking', 'liberals']
#
#
# @user @user She's been active on Instagram lately. And she is dropping an album sometime this year.
#
# OUR beta tokenizer ['user', 'user', 'She', 's', 'been', 'active', 'on', 'Instagram', 'lately', 'And', 'she', 'is', 'dropping', 'an', 'album', 'sometime', 'this', 'year']
# ...
# DESIRED  tokenizer ['@user', 'He', "didn't", 'just', 'lose', 'his', 'talent', '.', 'He', 'battled', 'demons', '&', 'played', 'on', 'an', 'embarrassment', 'of', 'a', 'franchise', '.', 'He', 'is', 'now', 'in', 'an', 'ideal', 'situation', '.', 'I', 'believe', 'he', 'is', 'still', 'an', 'elite', 'WR', 'but', 'I', 'guess', 'only', 'time', 'will', 'tell', '.']
#
#
# @user I think that some might be wearing nasks and carruing Antifa flags
#
# OUR beta tokenizer ['user', 'I', 'think', 'that', 'some', 'might', 'be', 'wearing', 'nasks', 'and', 'carruing', 'Antifa', 'flags']
# DESIRED  tokenizer ['@user', 'I', 'think', 'that', 'some', 'might', 'be', 'wearing', 'nasks', 'and', 'carruing', 'Antifa', 'flags']
#
#
# @user Because claims if sex assault and rape are only political weapons to them.
#
# OUR beta tokenizer ['user', 'Because', 'claims', 'if', 'sex', 'assault', 'and', 'rape', 'are', 'only', 'political', 'weapons', 'to', 'them']
# DESIRED  tokenizer ['@user', 'Because', 'claims', 'if', 'sex', 'assault', 'and', 'rape', 'are', 'only', 'political', 'weapons', 'to', 'them', '.']
#
#
# @user @user His staffers should remember that Trump is in favor of using enhanced interrogation techniques.
#
# OUR beta tokenizer ['user', 'user', 'His', 'staffers', 'should', 'remember', 'that', 'Trump', 'is', 'in', 'favor', 'of', 'using', 'enhanced', 'interrogation', 'techniques']
# DESIRED  tokenizer ['@user', '@user', 'His', 'staffers', 'should', 'remember', 'that', 'Trump', 'is', 'in', 'favor', 'of', 'using', 'enhanced', 'interrogation', 'techniques', '.']
#
#
# @user My guess a lot of unflattering facts will come out about Dr Ford in days to come.  As a father of a daughter...if some one roughed her up to the point she is claiming at 15...she could not have hid her emotional state from her parents.
#
# OUR beta tokenizer ['user', 'My', 'guess', 'a', 'lot', 'of', 'unflattering', 'facts', 'will', 'come', 'out', 'about', 'Dr', 'Ford', 'in', 'days', 'to', 'come', 'As', 'a', 'father', 'of', 'a', 'daughter', 'if', 'some', 'one', 'roughed', 'her', 'up', 'to', 'the', 'point', 'she', 'is', 'claiming', 'at', '15', 'she', 'could', 'not', 'have', 'hid', 'her', 'emotional', 'state', 'from', 'her', 'parents']
# DESIRED  tokenizer ['@user', 'My', 'guess', 'a', 'lot', 'of', 'unflattering', 'facts', 'will', 'come', 'out', 'about', 'Dr', 'Ford', 'in', 'days', 'to', 'come', '.', 'As', 'a', 'father', 'of', 'a', 'daughter', '...', 'if', 'some', 'one', 'roughed', 'her', 'up', 'to', 'the', 'point', 'she', 'is', 'claiming', 'at', '15', '...', 'she', 'could', 'not', 'have', 'hid', 'her', 'emotional', 'state', 'from', 'her', 'parents', '.']
#
#
# @user I think you are gravely mistaken You can't blame the rise of fascism  collective struggle of black people. All politics is identity politics and nobodies freedom"" has priority over an other. Capitalism has multiple axis of exploitation and if you ignore one you fail!""
#
# OUR beta tokenizer ['user', 'I', 'think', 'you', 'are', 'gravely', 'mistaken', 'You', 'can', 't', 'blame', 'the', 'rise', 'of', 'fascism', 'collective', 'struggle', 'of', 'black', 'people', 'All', 'politics', 'is', 'identity', 'politics', 'and', 'nobodies', 'freedom', 'has', 'priority', 'over', 'an', 'other', 'Capitalism', 'has', 'multiple', 'axis', 'of', 'exploitation', 'and', 'if', 'you', 'ignore', 'one', 'you', 'fail']
# DESIRED  tokenizer ['@user', 'I', 'think', 'you', 'are', 'gravely', 'mistaken', 'You', "can't", 'blame', 'the', 'rise', 'of', 'fascism', 'collective', 'struggle', 'of', 'black', 'people', '.', 'All', 'politics', 'is', 'identity', 'politics', 'and', 'nobodies', 'freedom', '"', '"', 'has', 'priority', 'over', 'an', 'other', '.', 'Capitalism', 'has', 'multiple', 'axis', 'of', 'exploitation', 'and', 'if', 'you', 'ignore', 'one', 'you', 'fail', '!', '"', '"']
#
#
# @user @user @user @user To be fair. I’m positive most liberals are just blobs of cells..
#
# OUR beta tokenizer ['user', 'user', 'user', 'user', 'To', 'be', 'fair', 'I', 'm', 'positive', 'most', 'liberals', 'are', 'just', 'blobs', 'of', 'cells']
# DESIRED  tokenizer ['@user', '@user', '@user', '@user', 'To', 'be', 'fair', '.', 'I', '’', 'm', 'positive', 'most', 'liberals', 'are', 'just', 'blobs', 'of', 'cells', '..']
#
#
# @user @user @user No. But I am. You are hilarious. Not in a good way.
#
# OUR beta tokenizer ['user', 'user', 'user', 'No', 'But', 'I', 'am', 'You', 'are', 'hilarious', 'Not', 'in', 'a', 'good', 'way']
# DESIRED  tokenizer ['@user', '@user', '@user', 'No', '.', 'But', 'I', 'am', '.', 'You', 'are', 'hilarious', '.', 'Not', 'in', 'a', 'good', 'way', '.']
#
#
# Confirm the MAN! THE LEFT WING ACTIVIST IS A LIAR WHO'S STORY CHANGES! NO HARD EVIDENCE! #ChristineBlaseyFord Innocent until proven guilty! #ConfirmKavanaugh  #MAGA  @user  #WeakRinos #Republicans
#
# OUR beta tokenizer ['Confirm', 'the', 'MAN', 'THE', 'LEFT', 'WING', 'ACTIVIST', 'IS', 'A', 'LIAR', 'WHO', 'S', 'STORY', 'CHANGES', 'NO', 'HARD', 'EVIDENCE', 'ChristineBlaseyFord', 'Innocent', 'until', 'proven', 'guilty', 'ConfirmKavanaugh', 'MAGA', 'user', 'WeakRinos', 'Republicans']
# DESIRED  tokenizer ['Confirm', 'the', 'MAN', '!', 'THE', 'LEFT', 'WING', 'ACTIVIST', 'IS', 'A', 'LIAR', "WHO'S", 'STORY', 'CHANGES', '!', 'NO', 'HARD', 'EVIDENCE', '!', '#ChristineBlaseyFord', 'Innocent', 'until', 'proven', 'guilty', '!', '#ConfirmKavanaugh', '#MAGA', '@user', '#WeakRinos', '#Republicans']
#
#
# @user Tell us how you really feel about #America Bill Maher 🙄 #MAGA #VoteRed
#
# OUR beta tokenizer ['user', 'Tell', 'us', 'how', 'you', 'really', 'feel', 'about', 'America', 'Bill', 'Maher', 'MAGA', 'VoteRed']
# DESIRED  tokenizer ['@user', 'Tell', 'us', 'how', 'you', 'really', 'feel', 'about', '#America', 'Bill', 'Maher', '🙄', '#MAGA', '#VoteRed']
#
#
# @user Then I see like this and lust over the girl with the long blond hair and the bare midriff and micro-mini and realize she is now 48 years older and could be a great grandmother today! 😱 People wonder why I love legs until I show them what I grew up with.
#
# OUR beta tokenizer ['user', 'Then', 'I', 'see', 'like', 'this', 'and', 'lust', 'over', 'the', 'girl', 'with', 'the', 'long', 'blond', 'hair', 'and', 'the', 'bare', 'midriff', 'and', 'micro', 'mini', 'and', 'realize', 'she', 'is', 'now', '48', 'years', 'older', 'and', 'could', 'be', 'a', 'great', 'grandmother', 'today', 'People', 'wonder', 'why', 'I', 'love', 'legs', 'until', 'I', 'show', 'them', 'what', 'I', 'grew', 'up', 'with']
# DESIRED  tokenizer ['@user', 'Then', 'I', 'see', 'like', 'this', 'and', 'lust', 'over', 'the', 'girl', 'with', 'the', 'long', 'blond', 'hair', 'and', 'the', 'bare', 'midriff', 'and', 'micro-mini', 'and', 'realize', 'she', 'is', 'now', '48', 'years', 'older', 'and', 'could', 'be', 'a', 'great', 'grandmother', 'today', '!', '😱', 'People', 'wonder', 'why', 'I', 'love', 'legs', 'until', 'I', 'show', 'them', 'what', 'I', 'grew', 'up', 'with', '.']
#
#
# @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user I dunno. I know who he is but I don't interact directly with him a lot. 🤷‍♂️
#
# OUR beta tokenizer ['user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'user', 'I', 'dunno', 'I', 'know', 'who', 'he', 'is', 'but', 'I', 'don', 't', 'interact', 'directly', 'with', 'him', 'a', 'lot']
# DESIRED  tokenizer ['@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', '@user', 'I', 'dunno', '.', 'I', 'know', 'who', 'he', 'is', 'but', 'I', "don't", 'interact', 'directly', 'with', 'him', 'a', 'lot', '.', '🤷', '\u200d', '♂', '️']
#
#
# @user She is laughing while she looks at up
#
# OUR beta tokenizer ['user', 'She', 'is', 'laughing', 'while', 'she', 'looks', 'at', 'up']
# DESIRED  tokenizer ['@user', 'She', 'is', 'laughing', 'while', 'she', 'looks', 'at', 'up']
#
#
# @user You are missing brains?
#
# OUR beta tokenizer ['user', 'You', 'are', 'missing', 'brains']
# DESIRED  tokenizer ['@user', 'You', 'are', 'missing', 'brains', '?']
#
#
# @user @user @user Yeah! Liberals are all Look at me! I'm a victim just because a man held me down, covered my mouth and tried to rip my clothes off to rape me. Boo hoo. And his friend turned up the music too loud to cover up my screams and it hurt my widdle ears""  Get over it already, amiright?""
#
# OUR beta tokenizer ['user', 'user', 'user', 'Yeah', 'Liberals', 'are', 'all', 'Look', 'at', 'me', 'I', 'm', 'a', 'victim', 'just', 'because', 'a', 'man', 'held', 'me', 'down', 'covered', 'my', 'mouth', 'and', 'tried', 'to', 'rip', 'my', 'clothes', 'off', 'to', 'rape', 'me', 'Boo', 'hoo', 'And', 'his', 'friend', 'turned', 'up', 'the', 'music', 'too', 'loud', 'to', 'cover', 'up', 'my', 'screams', 'and', 'it', 'hurt', 'my', 'widdle', 'ears', 'Get', 'over', 'it', 'already', 'amiright']
# DESIRED  tokenizer ['@user', '@user', '@user', 'Yeah', '!', 'Liberals', 'are', 'all', 'Look', 'at', 'me', '!', "I'm", 'a', 'victim', 'just', 'because', 'a', 'man', 'held', 'me', 'down', ',', 'covered', 'my', 'mouth', 'and', 'tried', 'to', 'rip', 'my', 'clothes', 'off', 'to', 'rape', 'me', '.', 'Boo', 'hoo', '.', 'And', 'his', 'friend', 'turned', 'up', 'the', 'music', 'too', 'loud', 'to', 'cover', 'up', 'my', 'screams', 'and', 'it', 'hurt', 'my', 'widdle', 'ears', '"', '"', 'Get', 'over', 'it', 'already', ',', 'amiright', '?', '"', '"']
#
#
# Same here but the more he talks the dumber he looks WWGIWGA MAGA
#
# OUR beta tokenizer ['Same', 'here', 'but', 'the', 'more', 'he', 'talks', 'the', 'dumber', 'he', 'looks', 'WWGIWGA', 'MAGA']
# DESIRED  tokenizer ['Same', 'here', 'but', 'the', 'more', 'he', 'talks', 'the', 'dumber', 'he', 'looks', 'WWGIWGA', 'MAGA']
#
#
# @user VOTE R in #Election2018 November  #GOP #RedWave  #Trump  #MAGA  👍🏻🇺🇸
#
# OUR beta tokenizer ['user', 'VOTE', 'R', 'in', 'Election2018', 'November', 'GOP', 'RedWave', 'Trump', 'MAGA']
# DESIRED  tokenizer ['@user', 'VOTE', 'R', 'in', '#Election2018', 'November', '#GOP', '#RedWave', '#Trump', '#MAGA', '👍', '🏻', '🇺', '🇸']
#
#
# @user Now this. A thousand percent agree with this. She is a passionate woman.
#
# OUR beta tokenizer ['user', 'Now', 'this', 'A', 'thousand', 'percent', 'agree', 'with', 'this', 'She', 'is', 'a', 'passionate', 'woman']
# DESIRED  tokenizer ['@user', 'Now', 'this', '.', 'A', 'thousand', 'percent', 'agree', 'with', 'this', '.', 'She', 'is', 'a', 'passionate', 'woman', '.']
#
#
# @user @user @user No- it’s wise all the time to not capitulate to liberal demands.. Example- allowing a few more days for the Kavanaugh hearings and offering the fake accuser the opportunity to testify under oath is smart politically.. but liberals demanded more. Then Grassley said “hell no”
#
# OUR beta tokenizer ['user', 'user', 'user', 'No', 'it', 's', 'wise', 'all', 'the', 'time', 'to', 'not', 'capitulate', 'to', 'liberal', 'demands', 'Example', 'allowing', 'a', 'few', 'more', 'days', 'for', 'the', 'Kavanaugh', 'hearings', 'and', 'offering', 'the', 'fake', 'accuser', 'the', 'opportunity', 'to', 'testify', 'under', 'oath', 'is', 'smart', 'politically', 'but', 'liberals', 'demanded', 'more', 'Then', 'Grassley', 'said', 'hell', 'no']
# DESIRED  tokenizer ['@user', '@user', '@user', 'No', '-', 'it', '’', 's', 'wise', 'all', 'the', 'time', 'to', 'not', 'capitulate', 'to', 'liberal', 'demands', '..', 'Example', '-', 'allowing', 'a', 'few', 'more', 'days', 'for', 'the', 'Kavanaugh', 'hearings', 'and', 'offering', 'the', 'fake', 'accuser', 'the', 'opportunity', 'to', 'testify', 'under', 'oath', 'is', 'smart', 'politically', '..', 'but', 'liberals', 'demanded', 'more', '.', 'Then', 'Grassley', 'said', '“', 'hell', 'no', '”']
#
#
# @user @user Love this woman Telling the truth every day WHY do conservatives have to point out the obvious.Are people really that stupid
#
# OUR beta tokenizer ['user', 'user', 'Love', 'this', 'woman', 'Telling', 'the', 'truth', 'every', 'day', 'WHY', 'do', 'conservatives', 'have', 'to', 'point', 'out', 'the', 'obvious', 'Are', 'people', 'really', 'that', 'stupid']
# DESIRED  tokenizer ['@user', '@user', 'Love', 'this', 'woman', 'Telling', 'the', 'truth', 'every', 'day', 'WHY', 'do', 'conservatives', 'have', 'to', 'point', 'out', 'the', 'obvious.Are', 'people', 'really', 'that', 'stupid']
#
#
# #MondayMotivation Liberals backing Kavanaugh Accuser"" high school episode to attack #SCOTUSpick - but praised #Adultery superstar #McCain - logic much? #MAGA #LiberalismIsAMentalDisorder
#
# OUR beta tokenizer ['MondayMotivation', 'Liberals', 'backing', 'Kavanaugh', 'Accuser', 'high', 'school', 'episode', 'to', 'attack', 'SCOTUSpick', 'but', 'praised', 'Adultery', 'superstar', 'McCain', 'logic', 'much', 'MAGA', 'LiberalismIsAMentalDisorder']
# DESIRED  tokenizer ['#MondayMotivation', 'Liberals', 'backing', 'Kavanaugh', 'Accuser', '"', '"', 'high', 'school', 'episode', 'to', 'attack', '#SCOTUSpick', '-', 'but', 'praised', '#Adultery', 'superstar', '#McCain', '-', 'logic', 'much', '?', '#MAGA', '#LiberalismIsAMentalDisorder']
#
#
# @user Give me a break!!!
#
# OUR beta tokenizer ['user', 'Give', 'me', 'a', 'break']
# DESIRED  tokenizer ['@user', 'Give', 'me', 'a', 'break', '!', '!', '!']
#
#
# @user He needs to go just as Joe P did
#
# OUR beta tokenizer ['user', 'He', 'needs', 'to', 'go', 'just', 'as', 'Joe', 'P', 'did']
# DESIRED  tokenizer ['@user', 'He', 'needs', 'to', 'go', 'just', 'as', 'Joe', 'P', 'did']
#
#
# @user Most definitely. I’m not advocating playing either game. Just thinking aloud they might play earlier.
#
# OUR beta tokenizer ['user', 'Most', 'definitely', 'I', 'm', 'not', 'advocating', 'playing', 'either', 'game', 'Just', 'thinking', 'aloud', 'they', 'might', 'play', 'earlier']
# DESIRED  tokenizer ['@user', 'Most', 'definitely', '.', 'I', '’', 'm', 'not', 'advocating', 'playing', 'either', 'game', '.', 'Just', 'thinking', 'aloud', 'they', 'might', 'play', 'earlier', '.']
#
#
# @user Maybe she NEVER BELIEVED in it. Maybe she just USED &amp; FOOLED too many in the West who were TOO desperate looking for a beacon"" for their own calculative agendas. And all the while, she bided her time and calculated ... until she got to where she is now, and so her TRUE COLOURS.""
#
# OUR beta tokenizer ['user', 'Maybe', 'she', 'NEVER', 'BELIEVED', 'in', 'it', 'Maybe', 'she', 'just', 'USED', 'amp', 'FOOLED', 'too', 'many', 'in', 'the', 'West', 'who', 'were', 'TOO', 'desperate', 'looking', 'for', 'a', 'beacon', 'for', 'their', 'own', 'calculative', 'agendas', 'And', 'all', 'the', 'while', 'she', 'bided', 'her', 'time', 'and', 'calculated', 'until', 'she', 'got', 'to', 'where', 'she', 'is', 'now', 'and', 'so', 'her', 'TRUE', 'COLOURS']
# DESIRED  tokenizer ['@user', 'Maybe', 'she', 'NEVER', 'BELIEVED', 'in', 'it', '.', 'Maybe', 'she', 'just', 'USED', '&', 'FOOLED', 'too', 'many', 'in', 'the', 'West', 'who', 'were', 'TOO', 'desperate', 'looking', 'for', 'a', 'beacon', '"', '"', 'for', 'their', 'own', 'calculative', 'agendas', '.', 'And', 'all', 'the', 'while', ',', 'she', 'bided', 'her', 'time', 'and', 'calculated', '...', 'until', 'she', 'got', 'to', 'where', 'she', 'is', 'now', ',', 'and', 'so', 'her', 'TRUE', 'COLOURS', '.', '"', '"']
#
#
# @user @user I’ll toast to me #Hillary
#
# OUR beta tokenizer ['user', 'user', 'I', 'll', 'toast', 'to', 'me', 'Hillary']
# DESIRED  tokenizer ['@user', '@user', 'I', '’', 'll', 'toast', 'to', 'me', '#Hillary']
#
#
# @user But he is still fucked up for not respecting LGBTQ
#
# OUR beta tokenizer ['user', 'But', 'he', 'is', 'still', 'fucked', 'up', 'for', 'not', 'respecting', 'LGBTQ']
# DESIRED  tokenizer ['@user', 'But', 'he', 'is', 'still', 'fucked', 'up', 'for', 'not', 'respecting', 'LGBTQ']
#
#
# @user why do conservatives not understand grammar
#
# OUR beta tokenizer ['user', 'why', 'do', 'conservatives', 'not', 'understand', 'grammar']
